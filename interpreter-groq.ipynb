# %%
import numpy as np
import pandas as pd
import sys
from openai import OpenAI
import os
import cv2
import re
import glob
from pathlib import Path
import matplotlib.pyplot as plt
import base64
from tqdm import tqdm
from dotenv import load_dotenv
import re
from groq import Groq

# %%
df = pd.read_csv('Data/New230SHEETS.csv')
df
# Out:
#       id         image_name                                            ocr_txt
# 0      1    Meme_Data_1.jpg  COWOK JAMAN SEKARANG PENGEN PUNYA PACAR CANTIK...
# 1      2    Meme_Data_2.jpg  ayat suci dalam bio bukan jaminan kalo\n dia o...
# 2      3    Meme_Data_3.jpg  Rare\n Medium Rare\n Medium\n Medium Well\n We...
# 3      4    Meme_Data_4.jpg  KITA MAH ORANG SUSAH\n INWE\n SUSAH DILAWAN MA...
# 4      5    Meme_Data_5.jpg  KALIAN GA PILIH DIA KARENA BEDA ALIRAN DAN FAN...
# ..   ...                ...                                                ...
# 225  226  Meme_Data_226.jpg  : "Kamu dari jawa ya!" Iyaa, kamu jawa juga?\n...
# 226  227  Meme_Data_227.jpg  Pas kecil liat orang dewasa pacaran, pas sudah...
# 227  228  Meme_Data_228.jpg  SINGAPORE AIRLINES\n 1. Untung 47 Trilliun 2. ...
# 228  229  Meme_Data_229.jpg  Yudi\n \n P\n \n Bls\n \n Besok pake baju apa\...
# 229  230  Meme_Data_230.jpg  Dua tipe manusia:\n Kamu rajin belajar biar bi...
#
# [230 rows x 3 columns]

# %%
# Check for missing values in the 'image_name' column
missing_image_names = df['image_name'].isna()

# Show rows where 'image_name' is missing
df_missing = df[missing_image_names]
print(df_missing)
# Out:
# Empty DataFrame
# Columns: [id, image_name, ocr_txt]
# Index: []

# %%
# Drop rows where 'image_name' is missing
df = df.dropna(subset=['ocr_txt'])

# Optionally, reset the index if you want a clean index after dropping
df = df.reset_index(drop=True)

# %%
# Load prompt template
with open('Prompt/interpreter.md', 'r', encoding='utf-8') as f:
    prompt_template = f.read()

# %%
# Test with first meme
test_row = df.iloc[0]
image_text = test_row['ocr_txt']
image_name = test_row['image_name']

# Replace placeholders
final_prompt = prompt_template.replace('{meme_text}', str(image_text))
final_prompt = final_prompt.replace('{image_path}', image_name)

# Show the final prompt
print("FINAL PROMPT THAT WILL BE SENT TO OPENAI:")
print("="*60)
print(final_prompt)
print("="*60)
# Out:
# FINAL PROMPT THAT WILL BE SENT TO OPENAI:
# ============================================================
# # Role
# You are an expert in interpreting meme since you are a master of analyzing the hidden message behind meme in Indonesian language
#
# # Task
# Your task is to generate a hidden message or the context of the meme
#
# ## Things Need to be Considered
# - There are 2 inputs which are meme image and meme text. Please, refer to those input for interpret meme
# - All of the memes are in Indonesian language. Therefore, please interpret meme in Indonesian language
# - The connection between meme image and meme text can be metaporical. Therefore, analyze both of those input carefully (i.e., a picture of a grumpy man is represent bad stuff and dislike)
#
# ## Example
#
# ### Example 1
# Input Image = meme_data_999.jpg
# Input Text = Sudah Kubilang jangan lawan King Indonesia
# Output = Tim sepak bola Indonesia adalah yang terbaik saat ini dan susah untuk dikalahkan. Oleh karena itu jangan coba-coba melawan tim sepak bola Indonesia
#
# ## Query
# Input Image = Meme_Data_1.jpg
# Input Text = COWOK JAMAN SEKARANG PENGEN PUNYA PACAR CANTIK GILIRAN DIMINTAIN DUIT SALON, BILANGNYA MATRE EMANG LO KIRA PERAWATAN DI SALON PAKE BPJS??
# Output =
# ============================================================

# %%
def encode_image_to_base64(image_path):
    """Encode image to base64"""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
# Load environment variables
load_dotenv()

# Initialize OpenAI client with API key from environment
client = Groq(
    api_key=os.getenv('GROQ_API_KEY')
)

# Verify API key is loaded
if not os.getenv('GROQ_API_KEY'):
    raise ValueError("GROQ_API_KEY not found in environment variables. Please create a .env file with your API key.")

def interpret_meme(row):
    """Interpret meme using OpenAI Vision API"""
    # Get image path and text from your CSV structure
    image_path = f"Data/Filtered 230/{row['image_name']}"
    image_text = row['ocr_txt']
    
    # Encode image
    base64_image = encode_image_to_base64(image_path)
    
    # Create prompt by replacing placeholders
    prompt = prompt_template.replace('{meme_text}', str(image_text))
    prompt = prompt.replace('{image_path}', row['image_name'])
    
    try:
        response = client.chat.completions.create(
            model="meta-llama/llama-4-scout-17b-16e-instruct",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": prompt
                        },
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}",
                                "detail": "high"
                            }
                        }
                    ]
                }
            ],
            max_tokens=2048,
            temperature=0
        )

        result = response.choices[0].message.content.strip()
        return result
    except Exception as e:
        print("Error:", e)
        return None
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 load_dotenv()
#       4 # Initialize OpenAI client with API key from environment
# ----> 5 client = Groq(
#       6     api_key=os.getenv('GROQ_API_KEY')
#       7 )
#       9 # Verify API key is loaded
#      10 if not os.getenv('GROQ_API_KEY'):
#
# File c:\Users\Irfan Robbani\anaconda3\envs\general\Lib\site-packages\groq\_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
print("GROQ_API_KEY:", os.getenv('GROQ_API_KEY'))
# Out:
# GROQ_API_KEY: None

# %%
sample_row = df.iloc[0]  # Use the first row for testing
output = interpret_meme(sample_row)
print(output)
# Out:
# **Pesan tersembunyi atau konteks meme:**
#
# Meme ini menyindir cowok-cowok zaman sekarang yang ingin punya pacar cantik, tapi tidak mau mengeluarkan uang untuk perawatan pacarnya di salon. Ketika dimintai uang untuk perawatan, mereka malah menuduh pacarnya matre (materialistis). Padahal, perawatan di salon itu memang mahal dan tidak bisa dibayar dengan BPJS (asuransi kesehatan pemerintah yang biasanya hanya untuk kebutuhan medis, bukan kecantikan). Meme ini menekankan bahwa kalau mau punya pacar cantik, harus siap juga dengan konsekuensi biaya perawatannya, bukan malah mengeluh atau menuduh matre.

# %%
# Process all memes
results = []
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing memes"):
    result = interpret_meme(row)
    results.append({
        'id': row['id'],
        'image_name': row['image_name'],
        'ocr_txt': row['ocr_txt'],
        'full_response': result
    })
    
    # Optional: Add delay to respect rate limits
    import time
    time.sleep(1)

results
# Out:
# Processing memes: 100%|██████████| 230/230 [20:11<00:00,  5.27s/it]
# [{'id': 1,
#   'image_name': 'Meme_Data_1.jpg',
#   'ocr_txt': 'COWOK JAMAN SEKARANG PENGEN PUNYA PACAR CANTIK GILIRAN DIMINTAIN DUIT SALON, BILANGNYA MATRE EMANG LO KIRA PERAWATAN DI SALON PAKE BPJS??',
#   'full_response': 'Output = Meme ini menyindir cowok-cowok zaman sekarang yang ingin punya pacar cantik, tapi tidak mau mengeluarkan uang untuk perawatan pacarnya di salon. Padahal, untuk tampil cantik butuh biaya, dan tidak bisa gratis seperti layanan BPJS. Jadi, meme ini menegaskan bahwa kalau mau punya pacar cantik, harus siap juga dengan konsekuensi biaya perawatannya, jangan malah menuduh matre.'},
#  {'id': 2,
#   'image_name': 'Meme_Data_2.jpg',
#   'ocr_txt': 'ayat suci dalam bio bukan jaminan kalo\n dia orang yang baik',
#   'full_response': 'Output = Meme ini menyampaikan pesan bahwa menampilkan ayat suci di bio media sosial seseorang tidak otomatis membuat orang tersebut benar-benar baik dalam kehidupan nyata. Seringkali, orang menggunakan simbol-simbol religius hanya untuk pencitraan, padahal sikap dan perilaku mereka belum tentu mencerminkan kebaikan atau nilai-nilai agama yang mereka tampilkan. Jadi, jangan mudah tertipu oleh tampilan luar di media sosial.'},
#  {'id': 3,
#   'image_name': 'Meme_Data_3.jpg',
#   'ocr_txt': 'Rare\n Medium Rare\n Medium\n Medium Well\n Well Done\n ONDE MANDE',
#   'full_response': 'Meme ini membandingkan tingkat kematangan daging steak dari "Rare" sampai "Well Done", lalu di bagian paling bawah ditambahkan gambar rendang dengan tulisan "ONDE MANDE". "Onde mande" adalah ungkapan khas Minang yang mengekspresikan kekagetan atau keheranan.\n\nPesan tersembunyi dari meme ini adalah:  \nRendang, makanan khas Indonesia (khususnya Minang), dimasak jauh lebih lama daripada steak "Well Done" sehingga teksturnya sangat kering dan bumbunya meresap sempurna. Meme ini secara lucu menyindir bahwa jika steak dimasak sampai level "onde mande" (seperti rendang), itu sudah sangat-sangat matang, bahkan jauh melampaui "Well Done". Ini juga menunjukkan kebanggaan terhadap rendang sebagai makanan Indonesia yang terkenal di dunia.'},
#  {'id': 4,
#   'image_name': 'Meme_Data_4.jpg',
#   'ocr_txt': 'KITA MAH ORANG SUSAH\n INWE\n SUSAH DILAWAN MAKSUDNYA',
#   'full_response': 'Output = Meme ini menggunakan permainan kata yang lucu. Kalimat "KITA MAH ORANG SUSAH" biasanya bermakna orang yang hidupnya sederhana atau kurang mampu. Namun, di bawahnya dijelaskan "SUSAH DILAWAN MAKSUDNYA", yang artinya mereka bukan orang yang susah secara ekonomi, tapi justru sulit untuk dikalahkan. Gambar sekelompok orang dengan ekspresi serius dan kompak memperkuat pesan bahwa mereka adalah kelompok yang kuat dan solid. Jadi, meme ini menyindir dengan cara lucu bahwa mereka bukan orang susah dalam arti sebenarnya, tapi justru lawan yang tangguh.'},
#  {'id': 5,
#   'image_name': 'Meme_Data_5.jpg',
#   'ocr_txt': 'KALIAN GA PILIH DIA KARENA BEDA ALIRAN DAN FANATISME CALON\n AKU GA PILIH DIA KARENA KANG CULIK, KLAN UCHIHA, DAN PECATAN PARJO\n KITA TIDAK SAMA',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap alasan-alasan orang dalam memilih atau tidak memilih seseorang (misal dalam pemilu atau pemilihan apapun). Meme ini membandingkan alasan umum yang sering dipakai orang lain, seperti perbedaan aliran atau fanatisme, dengan alasan pribadi yang kocak dan tidak masuk akal seperti "kang culik", "klan Uchiha", dan "pecatan Parjo" (referensi ke karakter fiksi atau lelucon internal). \n\nGambar pria serius menambah kesan bahwa si pembuat meme merasa dirinya berbeda dan lebih "unik" dalam mengambil keputusan, sehingga muncul kalimat "KITA TIDAK SAMA". Intinya, meme ini menertawakan betapa absurd dan beragamnya alasan orang dalam menentukan pilihan, serta menonjolkan keunikan alasan pribadi si pembuat meme.'},
#  {'id': 6,
#   'image_name': 'Meme_Data_6.jpg',
#   'ocr_txt': ' karena kamu ga pake helm,\n ga bawa SIM juga\n mau di bantu apa ikut sidang?',
#   'full_response': 'Output = Meme ini menggambarkan situasi ketika seseorang tertangkap polisi karena melanggar aturan lalu lintas, seperti tidak memakai helm dan tidak membawa SIM. Dengan ekspresi karakter Patrick yang kebingungan dan pasrah, serta polisi yang menawarkan dua pilihan (dibantu dengan "uang damai" atau ikut sidang), meme ini menyindir praktik pungli (uang damai) yang sering terjadi saat razia lalu lintas di Indonesia. Pesan tersembunyinya adalah, jika sudah melanggar banyak aturan, pada akhirnya kamu tidak punya banyak pilihan selain menerima konsekuensinya.'},
#  {'id': 7,
#   'image_name': 'Meme_Data_7.jpg',
#   'ocr_txt': 'KETIKA KAMU NYARI LAGU TAPI NGGAK TAHU JUDULNYA\n \n TONG NENG NONG NENG\n TENG NONG NENG\n YOUTUBE\n GOOGLE',
#   'full_response': 'Output = Meme ini menggambarkan situasi lucu ketika seseorang ingin mencari lagu di internet, tapi tidak tahu judulnya. Biasanya, orang hanya mengingat nada atau suara aneh dari lagu tersebut (seperti "tong neng nong neng teng nong neng") dan mencoba mencarinya di YouTube atau Google. Namun, karena hanya mengandalkan suara atau nada yang tidak jelas, hasil pencarian biasanya tidak memuaskan dan membuat frustasi. Pesan tersembunyinya adalah betapa sulitnya mencari lagu tanpa tahu judul atau lirik yang jelas, dan ini adalah pengalaman yang sering dialami banyak orang.'},
#  {'id': 8,
#   'image_name': 'Meme_Data_8.jpg',
#   'ocr_txt': 'PEKERJAAN PALING MUDAH ADALAH JUALAN ES BATU\n LAKU GA LAKU\n TETEP CAIR',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran lucu tentang pekerjaan yang mudah, yaitu berjualan es batu. Kalimat "Laku ga laku tetep cair" adalah permainan kata: es batu akan tetap mencair meskipun tidak laku terjual, dan kata "cair" juga bisa berarti mendapatkan uang (cair uangnya). Jadi, meme ini menyindir bahwa berjualan es batu tidak perlu khawatir soal hasil, karena es-nya pasti akan "cair" (meleleh) pada akhirnya, baik laku maupun tidak. Gambar kucing yang duduk santai di atas es batu menambah kesan santai dan lucu dari sindiran ini.'},
#  {'id': 9,
#   'image_name': 'Meme_Data_9.jpg',
#   'ocr_txt': 'DIBUTUHKAN\n KARYAWAN 3 ORANG\n PELAMAR:',
#   'full_response': 'Output = Meme ini menggambarkan situasi di mana lowongan pekerjaan yang hanya membutuhkan 3 orang, tetapi pelamarnya sangat banyak. Pesan tersembunyi dari meme ini adalah betapa sulitnya mencari pekerjaan saat ini, sehingga banyak orang yang berebut untuk satu posisi kerja yang tersedia. Ini juga menyindir kondisi ekonomi atau persaingan kerja yang sangat ketat di Indonesia.'},
#  {'id': 10,
#   'image_name': 'Meme_Data_10.jpg',
#   'ocr_txt': '1 kerja benar kerja keras\n 2 kenangan & nama baik\n 3 pake duid pajak perkaya diri sendiri, temen, & keluarga\n \n Pejabat Bangsat\n 3',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap pejabat korup di Indonesia. Meme ini menggambarkan bahwa pejabat yang tidak bermoral (disebut "Pejabat Bangsat") lebih memilih jalan yang salah, yaitu memperkaya diri sendiri, teman, dan keluarga dengan uang pajak rakyat, daripada bekerja keras dengan benar atau menjaga nama baik. Meme ini mengkritik perilaku korupsi yang sering terjadi di kalangan pejabat, di mana mereka lebih memilih keuntungan pribadi daripada integritas dan kerja keras.'},
#  {'id': 11,
#   'image_name': 'Meme_Data_11.jpg',
#   'ocr_txt': 'Tidur dengan beban masa lalu',
#   'full_response': 'Meme ini menggambarkan seseorang yang tidur di atas ranjang penuh paku, yang jelas sangat tidak nyaman dan menyakitkan. Teks "Tidur dengan beban masa lalu" mengibaratkan bahwa seseorang yang masih memikirkan atau terbebani oleh masa lalunya akan merasa sulit untuk beristirahat dengan tenang, seperti tidur di atas ranjang paku. Pesan tersembunyi dari meme ini adalah, beban masa lalu bisa membuat hidup terasa berat dan tidak nyaman, bahkan saat seharusnya kita bisa beristirahat atau tenang.'},
#  {'id': 12,
#   'image_name': 'Meme_Data_12.jpg',
#   'ocr_txt': 'semua aku telen sendiri:\n Aku\n Sedih\n Capek\n Takut\n Marah\n Muak\n Overthinking\n Gagal',
#   'full_response': 'Meme ini menggambarkan seseorang yang selalu memendam dan menahan semua perasaan negatif sendirian, seperti sedih, capek, takut, marah, muak, overthinking, dan gagal, tanpa pernah membagikannya ke orang lain. Pesan tersembunyinya adalah banyak orang yang terlihat baik-baik saja di luar, padahal sebenarnya mereka menanggung beban emosi yang berat sendirian.'},
#  {'id': 13,
#   'image_name': 'Meme_Data_13.jpg',
#   'ocr_txt': 'Postingan wajib menjelang idul adha',
#   'full_response': 'Output = Menjelang Idul Adha, banyak orang di Indonesia sering memposting foto-foto kambing atau domba karena hewan tersebut identik dengan kurban. Meme ini menampilkan gambar domba lucu yang seolah-olah menjadi “posting-an wajib” setiap menjelang Idul Adha, menyindir kebiasaan netizen yang selalu memposting hal serupa setiap tahun. Pesan tersembunyinya adalah, setiap Idul Adha pasti timeline media sosial dipenuhi foto-foto hewan kurban, bahkan yang lucu sekalipun.'},
#  {'id': 14,
#   'image_name': 'Meme_Data_14.jpg',
#   'ocr_txt': '"Piye Kabare?\n Penak Jamanku Toh?" Penjajah Belanda, 1602',
#   'full_response': 'Output = Meme ini menyindir situasi di Indonesia saat ini dengan cara humoris. Kalimat "Piye Kabare? Penak Jamanku Toh?" biasanya diucapkan oleh mantan pejabat orde baru untuk membandingkan masa pemerintahannya dengan masa sekarang. Namun, dalam meme ini, yang mengucapkan adalah penjajah Belanda tahun 1602, seolah-olah masa penjajahan Belanda lebih baik daripada kondisi sekarang. Pesan tersembunyinya adalah kritik terhadap kondisi Indonesia saat ini yang dianggap oleh sebagian orang tidak lebih baik dibanding masa lalu, bahkan masa penjajahan.'},
#  {'id': 15,
#   'image_name': 'Meme_Data_15.jpg',
#   'ocr_txt': 'M*ling Uang Rakyat Rp316,9 Miliar Korupsi Uang APD Covid-19 di Kemenkes Divonis\n 3 Tahun Penjara.\n Dituduh M*ling Ayam Divonis 5 Tahun Penjara.',
#   'full_response': 'Output = Meme ini menyindir ketidakadilan hukum di Indonesia. Orang yang mencuri uang rakyat dalam jumlah besar (korupsi ratusan miliar) hanya dihukum 3 tahun penjara, sedangkan orang kecil yang dituduh mencuri ayam justru dihukum lebih berat, yaitu 5 tahun penjara. Pesan tersembunyi dari meme ini adalah sistem hukum di Indonesia sering kali tidak adil dan lebih berat kepada rakyat kecil, sementara koruptor yang merugikan negara justru mendapat hukuman ringan.'},
#  {'id': 16,
#   'image_name': 'Meme_Data_16.jpg',
#   'ocr_txt': 'INI FOTOKOPI\n 20000 \n INI ASLI\n IJAZAH',
#   'full_response': 'Output = Meme ini menyindir realita di masyarakat bahwa uang sering dianggap lebih penting daripada ijazah atau pendidikan. Di gambar, uang 20.000 rupiah disebut sebagai "fotokopi" (tidak asli), sedangkan ijazah disebut sebagai "asli". Pesan tersembunyinya adalah, meskipun ijazah dianggap sebagai bukti asli keberhasilan, pada kenyataannya uanglah yang sering lebih dihargai atau dicari orang. Meme ini juga menyoroti fenomena bahwa di dunia kerja, kadang uang lebih menentukan daripada sekadar ijazah.'},
#  {'id': 17,
#   'image_name': 'Meme_Data_17.jpg',
#   'ocr_txt': 'Antar ortu sepuh cekup biasa ke RS\n Menunggu lebih lama dari biasanya\n Tiba2 banyak dokter dan perawat dateng ngerumunin ortu lu',
#   'full_response': 'Output = Meme ini menggambarkan perubahan perasaan seseorang yang awalnya santai saat mengantar orang tua yang sudah lanjut usia ke rumah sakit untuk cek rutin. Namun, ketika menunggu lebih lama dari biasanya dan tiba-tiba banyak dokter serta perawat datang mengerumuni orang tua tersebut, perasaan berubah menjadi cemas dan takut. Pesan tersembunyinya adalah kekhawatiran mendalam yang muncul ketika situasi yang awalnya biasa saja berubah menjadi darurat atau serius, terutama terkait kesehatan orang tua.'},
#  {'id': 18,
#   'image_name': 'Meme_Data_18.jpg',
#   'ocr_txt': 'SERIUS NANYA, CEWEK TUH LEBIH SUKA DICUBIT PIPINYA ATAU DI USAP-USAP\n KEPALANYA?\n LEBIH SUKA DITRANSFER REKENINGNYA',
#   'full_response': 'Meme ini menyindir fenomena di mana banyak perempuan zaman sekarang lebih menghargai hadiah atau uang daripada perhatian fisik seperti dicubit pipi atau diusap kepalanya. Pertanyaan awal seolah-olah ingin tahu bentuk perhatian fisik mana yang lebih disukai perempuan, namun jawabannya justru “lebih suka ditransfer rekeningnya” yang berarti mereka lebih suka diberi uang. Meme ini menggambarkan realita atau stereotip bahwa materi seringkali dianggap lebih penting daripada perhatian emosional atau fisik.'},
#  {'id': 19,
#   'image_name': 'Meme_Data_19.jpg',
#   'ocr_txt': 'jangan terlalu seneng bro, gua juga awalnya begini',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang sedang duduk sendirian dan tampak bahagia sambil bermain HP. Teksnya “jangan terlalu seneng bro, gua juga awalnya begini” menyiratkan pesan bahwa kebahagiaan yang dirasakan saat ini mungkin hanya sementara. Biasanya, ini digunakan untuk menasihati teman yang sedang merasakan kebahagiaan awal dalam suatu hubungan atau pengalaman baru, tapi si pembuat meme sudah pernah merasakan hal yang sama dan akhirnya berakhir tidak sesuai harapan. Intinya, jangan terlalu larut dalam kebahagiaan awal karena bisa saja nanti berakhir kecewa.'},
#  {'id': 20,
#   'image_name': 'Meme_Data_20.jpg',
#   'ocr_txt': 'HAMPIR TELAT NONTONIN\n ORANG BERANGKAT KERJA',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang santai di pagi hari, menikmati waktu luangnya sambil minum kopi, dan hanya menonton orang lain yang sibuk berangkat kerja. Pesan tersembunyinya adalah sindiran untuk orang yang tidak bekerja atau sedang libur, sehingga mereka merasa "pekerjaan" mereka hanya menonton orang lain berangkat kerja. Ada nuansa humor karena biasanya orang terburu-buru di pagi hari, tapi tokoh di meme justru santai dan hampir "telat" hanya untuk menonton orang lain bekerja.'},
#  {'id': 21,
#   'image_name': 'Meme_Data_21.jpg',
#   'ocr_txt': 'Saat aku dan komunku nyari kontrak resmi yang mengharuskan kita nurut apapun kata pemerintah',
#   'full_response': 'Output = Meme ini menggambarkan situasi di mana seseorang dan komunitasnya sedang mencari-cari kontrak resmi yang isinya mewajibkan mereka untuk selalu patuh pada pemerintah. Gambar karakter Scooby-Doo dan teman-temannya yang sedang mencari sesuatu di tanah secara kocak menggambarkan bahwa kontrak seperti itu sangat sulit ditemukan, bahkan mungkin tidak ada. Pesan tersembunyinya adalah, aturan yang terlalu mengekang dan memaksa untuk selalu patuh pada pemerintah dianggap tidak realistis atau tidak diinginkan oleh komunitas tersebut.'},
#  {'id': 22,
#   'image_name': 'Meme_Data_22.jpg',
#   'ocr_txt': 'Never Ask A Woman\n Her Age \n A Man, His Salary\n Bapak ini,\n dia ngapain pas\n bulan mei 1998',
#   'full_response': 'Output = Meme ini menyindir bahwa ada beberapa pertanyaan yang dianggap tabu atau sensitif untuk ditanyakan, seperti umur wanita dan gaji pria. Namun, meme ini menambahkan satu pertanyaan sensitif lain yang berkaitan dengan tokoh pada gambar, yaitu "Bapak ini, dia ngapain pas bulan Mei 1998". Ini merujuk pada peristiwa penting di Indonesia, yaitu kerusuhan Mei 1998, di mana peran beberapa tokoh masih menjadi kontroversi dan sering dipertanyakan publik. Jadi, meme ini menyiratkan bahwa menanyakan peran tokoh tersebut di masa itu sama sensitifnya dengan menanyakan umur wanita atau gaji pria.'},
#  {'id': 23,
#   'image_name': 'Meme_Data_23.jpg',
#   'ocr_txt': 'Peran Budi Arie di Kasus Jud 1: Terima Jatah 50 Persen dari Penjagaan Situs\n OH NO!\n Prabowo Tugaskan Menkop Budi Arie Hadiri Pelantikan Paus Leo XIV di Vatikan\n ANYWAY',
#   'full_response': 'Meme ini menyindir bagaimana isu atau skandal yang melibatkan seorang pejabat (dalam hal ini Budi Arie) bisa dengan mudah dialihkan atau dilupakan publik ketika ada tugas atau berita baru yang lebih "positif" atau prestisius. Pada bagian atas, Budi Arie terlihat cemas karena dikaitkan dengan kasus judi online, namun pada bagian bawah, ia tampak santai dan tersenyum ketika diberi tugas menghadiri acara penting di Vatikan. Pesan tersembunyi dari meme ini adalah kritik terhadap bagaimana isu-isu serius sering kali tidak ditindaklanjuti secara serius dan mudah tergantikan oleh pencitraan atau tugas-tugas baru yang lebih baik di mata publik.'},
#  {'id': 24,
#   'image_name': 'Meme_Data_24.jpg',
#   'ocr_txt': 'yo ndak tau....\n KOK TANYA SAYA.....',
#   'full_response': 'Output = Meme ini biasanya digunakan ketika seseorang ditanya tentang sesuatu yang dia sendiri tidak tahu jawabannya, dan merasa pertanyaannya tidak relevan atau tidak seharusnya ditujukan kepadanya. Ekspresi wajah pada gambar memperkuat kesan bingung dan sedikit kesal, seolah-olah berkata, "Kenapa harus saya yang ditanya? Saya juga tidak tahu." Meme ini sering dipakai untuk menanggapi pertanyaan-pertanyaan yang sulit, aneh, atau tidak masuk akal.'},
#  {'id': 25,
#   'image_name': 'Meme_Data_25.jpg',
#   'ocr_txt': '2023: 1.110 kasus keracunan makanan dalam setahun (BPOM). 2025: 1.372 kasus keracunan MBG dalam beberapa bulan.\n sampai jumpa di fakta selanjutnya.',
#   'full_response': 'Output = Meme ini menyindir situasi di mana jumlah kasus keracunan makanan pada tahun 2023 lebih sedikit dibandingkan dengan kasus keracunan MBG (diduga makanan atau produk tertentu) yang melonjak drastis hanya dalam beberapa bulan di tahun 2025. Gambar karakter yang memasang wajah santai lalu pergi begitu saja menggambarkan sikap tidak peduli atau lepas tangan terhadap masalah serius ini. Pesan tersembunyi dari meme ini adalah kritik terhadap pihak berwenang atau pemerintah yang dianggap tidak serius menangani masalah keracunan makanan yang semakin parah, bahkan terkesan menyepelekan fakta-fakta yang ada.'},
#  {'id': 26,
#   'image_name': 'Meme_Data_26.jpg',
#   'ocr_txt': 'Apakah kalian\n melihat ormasnya?\n Dimana',
#   'full_response': 'Output = Meme ini menggunakan karakter Dora dari acara anak-anak "Dora the Explorer" yang terkenal sering bertanya kepada penonton, seperti "Apakah kalian melihat gunungnya? Dimana?". Namun, dalam meme ini, kata "gunung" diganti dengan "ormas" (organisasi masyarakat), yang biasanya dikaitkan dengan isu-isu sosial atau politik di Indonesia. Pesan tersembunyi dari meme ini adalah menyindir keberadaan ormas yang sering muncul tiba-tiba atau sulit ditemukan saat dibutuhkan, atau bisa juga menyindir ormas yang sering dicari-cari keberadaannya dalam situasi tertentu. Meme ini menggunakan gaya bertanya polos ala Dora untuk menyoroti isu sosial dengan cara yang lucu dan satir.'},
#  {'id': 27,
#   'image_name': 'Meme_Data_27.jpg',
#   'ocr_txt': 'Emak: TV itu kalo engga kamu tonton ya dimatiin, dia juga butuh istirahat.\n Kulkas di dapurnya dari tahun 2003:',
#   'full_response': 'Output = Meme ini menyindir kebiasaan orang tua yang sering meminta anaknya mematikan TV agar "istirahat", seolah-olah TV juga butuh waktu untuk beristirahat seperti manusia. Namun, di sisi lain, kulkas di rumah yang sudah menyala terus-menerus sejak tahun 2003 tidak pernah dimatikan dan tetap dibiarkan bekerja tanpa henti. Gambar Mr. Krabs yang terlihat sangat tua dan lelah menggambarkan kulkas yang sudah tua dan kelelahan karena terus bekerja tanpa pernah "istirahat". Pesan tersembunyinya adalah sindiran lucu tentang standar ganda dalam memperlakukan barang elektronik di rumah.'},
#  {'id': 28,
#   'image_name': 'Meme_Data_28.jpg',
#   'ocr_txt': 'Makan apa, bang?\n Makan gaji buta',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang sedang membeli makanan di warteg, namun ketika ditanya "Makan apa, bang?", dia menjawab "Makan gaji buta". Ini adalah plesetan dari pertanyaan tentang makanan, padahal "makan gaji buta" adalah istilah untuk orang yang menerima gaji tanpa benar-benar bekerja keras. Pesan tersembunyi dari meme ini adalah sindiran terhadap orang-orang yang malas bekerja tapi tetap menerima gaji, seolah-olah itu adalah "menu" yang mereka konsumsi setiap hari.'},
#  {'id': 29,
#   'image_name': 'Meme_Data_29.jpg',
#   'ocr_txt': 'DI MATA ORANG BIASA HANYALAH KERUPUK UDANG TAPI DI MATA ORANG INDONESIA INI ADALAH ALAT UNTUK NYEROK NASI',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah bahwa orang Indonesia sering memanfaatkan benda-benda sederhana di sekitar mereka untuk keperluan yang tidak biasa. Dalam hal ini, kerupuk udang yang seharusnya dimakan, sering digunakan sebagai alat untuk mengambil nasi dari piring, terutama saat makan bersama. Meme ini menyoroti kreativitas dan kebiasaan unik masyarakat Indonesia dalam kehidupan sehari-hari.'},
#  {'id': 30,
#   'image_name': 'Meme_Data_30.jpg',
#   'ocr_txt': 'TIDDDAAAAAAA\n POKONYAA KU\n TERHINAAAAAA\n WAAAAAAAAAA\n yauda kan tinggal tunjukin aja kalo ada\n WAAAAAAAAAA\n WAAAAAAAAAA',
#   'full_response': 'Meme ini menggambarkan seseorang yang merasa sangat tersinggung dan dramatis (ditunjukkan dengan teriakan "TERHINAAAAAA WAAAAAA"), padahal masalahnya sebenarnya bisa diselesaikan dengan mudah dan logis (dengan kalimat "yauda kan tinggal tunjukin aja kalo ada"). Pesan tersembunyi dari meme ini adalah: seringkali orang bereaksi berlebihan terhadap suatu masalah, padahal solusinya sederhana jika dipikirkan dengan tenang. Meme ini sindiran untuk orang yang suka drama atau playing victim tanpa alasan yang jelas.'},
#  {'id': 31,
#   'image_name': 'Meme_Data_31.jpg',
#   'ocr_txt': 'Aduh nginjak apa nih berat banget\n Menginjak kepala 3',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah tentang perasaan berat atau sulit ketika seseorang mulai memasuki usia 30-an (dalam bahasa Indonesia sering disebut "kepala 3"). Istilah "menginjak kepala 3" adalah ungkapan untuk orang yang usianya sudah memasuki 30 tahun. Meme ini menggambarkan bahwa memasuki usia 30 tahun terasa berat, seperti menginjak sesuatu yang sangat berat. Jadi, meme ini menyindir realita bahwa bertambahnya usia, khususnya memasuki usia 30 tahun, sering dianggap sebagai beban atau tantangan tersendiri dalam hidup.'},
#  {'id': 32,
#   'image_name': 'Meme_Data_32.jpg',
#   'ocr_txt': 'TUJUAN HIDUPKU\n ADALAH MENCARI TUJUAN HIDUP',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang terlihat percaya diri dan serius, namun isi teksnya justru menunjukkan kebingungan atau paradoks: "Tujuan hidupku adalah mencari tujuan hidup." Pesan tersembunyi dari meme ini adalah banyak orang yang sebenarnya belum tahu apa tujuan hidupnya, dan justru proses mencari tujuan itu sendiri menjadi tujuan hidup mereka. Meme ini juga menyindir realita anak muda zaman sekarang yang sering merasa bingung dengan arah hidupnya, namun tetap berusaha terlihat yakin di depan orang lain.'},
#  {'id': 33,
#   'image_name': 'Meme_Data_33.jpg',
#   'ocr_txt': '"waduh ini kok***** permanen?"\n "sedihnya"\n "spidolnya bu?"',
#   'full_response': 'Output = Meme ini menggambarkan situasi di mana seorang guru tanpa sengaja menulis di papan tulis menggunakan spidol permanen, bukan spidol khusus papan tulis. Hal ini membuat tulisan di papan tidak bisa dihapus, sehingga menimbulkan rasa sedih dan penyesalan. Secara tersembunyi, meme ini juga bisa menggambarkan perasaan menyesal setelah melakukan kesalahan yang tidak bisa diperbaiki, baik dalam kehidupan sehari-hari maupun dalam situasi lain. Pesan tersembunyinya adalah kadang kita melakukan kesalahan kecil yang ternyata berdampak besar dan sulit diperbaiki, sehingga menimbulkan penyesalan.'},
#  {'id': 34,
#   'image_name': 'Meme_Data_34.jpg',
#   'ocr_txt': 'Cari cat apa pak?\n \n Cari chat\n yg gak dibales',
#   'full_response': 'Output = Meme ini bermain dengan kata "cat" dan "chat" yang terdengar mirip dalam pengucapan bahasa Indonesia. Di gambar, pegawai toko bertanya "Cari cat apa pak?" (cat = paint), tapi si bapak menjawab "Cari chat yg gak dibales" (chat = pesan yang tidak dibalas). Pesan tersembunyi dari meme ini adalah tentang perasaan seseorang yang chat-nya diabaikan atau tidak dibalas, sehingga dia bercanda seolah-olah "chat yang tidak dibalas" itu bisa dicari di toko cat. Meme ini menggambarkan kegalauan atau kekecewaan karena pesan yang diabaikan, dengan cara yang lucu dan relate dengan kehidupan sehari-hari.'},
#  {'id': 35,
#   'image_name': 'Meme_Data_35.jpg',
#   'ocr_txt': 'nyari apa bu?\n nyari energi buat hapusin foto di galeri',
#   'full_response': 'Output = Meme ini menggambarkan betapa beratnya perasaan atau rasa malas seseorang ketika harus menghapus foto-foto di galeri HP. Biasanya, menghapus foto di galeri terasa seperti pekerjaan yang sangat melelahkan dan butuh banyak energi, padahal sebenarnya itu adalah hal yang sederhana. Lewat percakapan di tukang sayur, meme ini menyindir kebiasaan orang yang suka menunda-nunda pekerjaan kecil karena merasa terlalu berat atau malas melakukannya.'},
#  {'id': 36,
#   'image_name': 'Meme_Data_36.jpg',
#   'ocr_txt': 'HATI-HATI 100 M\n ADA PEKERJAAN\n pengangguran :',
#   'full_response': 'Output = Meme ini memparodikan tanda peringatan di jalan yang bertuliskan "HATI-HATI 100 M ADA PEKERJAAN", yang sebenarnya maksudnya adalah ada pekerjaan konstruksi atau perbaikan jalan di depan. Namun, kata "pekerjaan" diartikan secara harfiah oleh orang pengangguran (tidak punya pekerjaan), sehingga dia merasa senang dan berharap akhirnya akan menemukan pekerjaan di depan. Meme ini menyindir realita para pengangguran yang sangat berharap menemukan pekerjaan di mana saja, bahkan dari tanda peringatan di jalan.'},
#  {'id': 37,
#   'image_name': 'Meme_Data_37.jpg',
#   'ocr_txt': 'Vaksin Gratis?\n Sudah diuji coba di negara miskin kayak INDONESIA belom?',
#   'full_response': 'Output = Meme ini menyindir ketidakpercayaan masyarakat terhadap vaksin gratis, dengan mempertanyakan apakah vaksin tersebut sudah diuji coba di negara berkembang atau miskin seperti Indonesia. Ekspresi anak kecil yang skeptis memperkuat pesan bahwa ada keraguan dan kecurigaan terhadap kualitas atau keamanan vaksin gratis yang diberikan, seolah-olah Indonesia sering dijadikan "kelinci percobaan" oleh negara-negara maju. Pesan tersembunyi dari meme ini adalah kritik terhadap ketidakadilan global dan rasa tidak percaya terhadap program kesehatan yang datang dari luar negeri.'},
#  {'id': 38,
#   'image_name': 'Meme_Data_38.jpg',
#   'ocr_txt': 'KETIKA DULU KAMU SERING\n NGATAIN BURUH\n "KOK DEMO MULU"\n TAPI SEKARANG KAMU ADALAH BAGIAN DARI MEREKA',
#   'full_response': 'Output = Meme ini menggambarkan perasaan malu atau menyesal ketika dulu sering meremehkan atau mengkritik buruh yang sering melakukan demo, namun sekarang justru menjadi bagian dari mereka dan mengalami sendiri alasan-alasan kenapa buruh sering melakukan aksi demo. Gambar wajah sedih atau menahan tangis memperkuat pesan bahwa kadang kita baru mengerti situasi orang lain setelah mengalaminya sendiri.'},
#  {'id': 39,
#   'image_name': 'Meme_Data_39.jpg',
#   'ocr_txt': 'KALO NGGAK BISA MENGURANGI\n ANGKA KEMISKINAN\n \n DITURUNKAN SAJA STANDAR Tue-Thur KEMISKINANNYA',
#   'full_response': 'Output = Meme ini menyindir pemerintah atau pihak berwenang yang tidak mampu menurunkan angka kemiskinan secara nyata. Sebagai solusi "cerdas", mereka malah menurunkan standar kemiskinan agar secara statistik jumlah orang miskin terlihat berkurang, padahal kenyataannya tidak ada perubahan signifikan di lapangan. Meme ini menyoroti cara berpikir yang manipulatif dan tidak menyelesaikan masalah sebenarnya.'},
#  {'id': 40,
#   'image_name': 'Meme_Data_40.jpg',
#   'ocr_txt': 'DASAR ANAK PKI\n saya sudah biasa difitnah\n PLANGA\n PLONGO!\n biar prestasi yg bicara\n IJAZAH PALSU!\n saya dihina sehina hinanya',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang sering difitnah dan dihina dengan berbagai tuduhan, seperti "anak PKI", "planga plongo", dan "ijazah palsu". Namun, orang tersebut tetap tenang dan memilih untuk membiarkan prestasinya yang berbicara, bukan membalas hinaan. Pesan tersembunyi dari meme ini adalah tentang ketegaran menghadapi fitnah dan hinaan, serta pentingnya membuktikan diri melalui prestasi, bukan dengan membalas ujaran negatif.'},
#  {'id': 41,
#   'image_name': 'Meme_Data_41.jpg',
#   'ocr_txt': 'CUMA DI INDONESIA\n MOHON PERHATIKAN TANGGA\n ORANG TAAT ATURAN DIKETAWAIN',
#   'full_response': 'Output = Meme ini menyindir budaya di Indonesia di mana orang yang mematuhi aturan justru sering dianggap aneh atau bahkan ditertawakan. Dalam gambar, ada seseorang yang benar-benar memperhatikan tangga sesuai dengan perintah di papan, namun tindakannya terlihat lucu. Pesan tersembunyi dari meme ini adalah kritik terhadap masyarakat yang kurang menghargai orang yang taat aturan, padahal seharusnya itu adalah hal yang baik.'},
#  {'id': 42,
#   'image_name': 'Meme_Data_42.jpg',
#   'ocr_txt': 'DI MEJA RAPAT, JAS DAN DASI JADI SELIMUT, MEREKA TERLELAP DIKURSI EMPUK. SEMENTARA RAKYAT MENUNGGU SOLUSI, MEREKA SIBUK MELANJUTKAN\n TIDUR SIANG YANG DIBAYAR MAHAL.',
#   'full_response': 'Meme ini menyindir para pejabat atau anggota dewan yang seharusnya bekerja dan mencari solusi untuk rakyat, namun justru terlihat malas dan tidur saat rapat. Jas dan dasi yang seharusnya melambangkan profesionalisme malah jadi “selimut” untuk tidur siang di kursi empuk, padahal mereka digaji mahal dari uang rakyat. Pesan tersembunyinya adalah kritik terhadap kinerja pejabat yang tidak serius bekerja dan lebih mementingkan kenyamanan pribadi daripada tanggung jawab kepada masyarakat.'},
#  {'id': 43,
#   'image_name': 'Meme_Data_43.jpg',
#   'ocr_txt': 'KITA YANG BAYAR, KITA YANG LAPOR, KITA JUGA YANG HARUS AWASIN\n PAJAK',
#   'full_response': 'Output = Meme ini menyindir sistem perpajakan di Indonesia yang dianggap membebani masyarakat. Orang-orang harus membayar pajak, melaporkan sendiri, dan bahkan harus mengawasi penggunaannya, seolah-olah semua tanggung jawab ada di tangan rakyat, bukan pemerintah. Ekspresi orang di gambar menambah kesan heran dan tidak masuk akal atas situasi ini.'},
#  {'id': 44,
#   'image_name': 'Meme_Data_44.jpg',
#   'ocr_txt': 'SDM RENDAH & SDM TINGGI',
#   'full_response': 'Meme ini menggunakan dua sendok yang ditancapkan di tanah, satu lebih pendek (rendah) dan satu lebih tinggi. Teks "SDM RENDAH & SDM TINGGI" adalah plesetan dari istilah Sumber Daya Manusia (SDM) rendah dan tinggi, yang biasanya merujuk pada kualitas atau kemampuan manusia. Namun, di meme ini, SDM hanya diartikan secara harfiah sebagai "sendok" yang rendah dan tinggi.\n\nPesan tersembunyi dari meme ini adalah sindiran terhadap penggunaan istilah-istilah serius seperti SDM dalam kehidupan sehari-hari, namun dipelesetkan menjadi sesuatu yang konyol dan tidak sesuai konteks. Meme ini juga menyoroti kebiasaan orang Indonesia yang suka membuat lelucon dari istilah-istilah formal.'},
#  {'id': 45,
#   'image_name': 'Meme_Data_45.jpg',
#   'ocr_txt': 'Yang pakai AI\n akan kalah\n dengan yang punya koneksi\n Kang AI',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap realita di Indonesia, di mana kemampuan atau teknologi canggih seperti AI (Artificial Intelligence) masih bisa kalah dengan orang-orang yang punya "koneksi" atau relasi kuat (orang dalam). Istilah "Kang AI" di sini adalah plesetan, seolah-olah menyindir bahwa yang benar-benar berkuasa adalah mereka yang punya akses atau kenalan, bukan yang punya kemampuan teknis. Gambar wajah dengan ekspresi datar juga menambah kesan pasrah atau sarkastik terhadap situasi ini.'},
#  {'id': 46,
#   'image_name': 'Meme_Data_46.jpg',
#   'ocr_txt': 'makasih sayang udah suport sama nemenin aku dari nol\n \n bapak gpp\n asal km jadi anak sukses\n \n sip kerja lagi',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap kebiasaan banyak orang yang ketika sudah sukses, mereka lebih mengapresiasi pasangan yang menemani dari nol, padahal sebenarnya orang tua—khususnya ayah—yang bekerja keras dan berkorban sejak awal agar anaknya bisa sukses. Ayah digambarkan sebagai sosok yang ikhlas, meski tidak mendapat pengakuan, tetap bekerja keras demi anaknya. Meme ini menyoroti pengorbanan orang tua yang sering terlupakan atau tidak dihargai secara eksplisit oleh anak-anaknya.'},
#  {'id': 47,
#   'image_name': 'Meme_Data_47.jpg',
#   'ocr_txt': 'DIPIKIR-PIKIR TERNYATA TAS SEKOLAH YANG PALING BERAT ADALAH BEBAN HIDUP GUA YANG PALING RINGAN',
#   'full_response': 'Output = Meme ini menggambarkan perasaan seseorang yang awalnya mengira tas sekolah adalah beban terberat dalam hidupnya, namun setelah dipikir-pikir, ternyata beban hidup yang ia alami jauh lebih berat. Ekspresi wajah pada gambar menunjukkan rasa pasrah dan lelah, seolah-olah sudah tidak kaget lagi dengan kenyataan hidup yang berat. Meme ini menyindir realita kehidupan, terutama bagi pelajar atau anak muda yang mulai merasakan tekanan hidup yang lebih berat daripada sekadar urusan sekolah.'},
#  {'id': 48,
#   'image_name': 'Meme_Data_48.jpg',
#   'ocr_txt': "I'm not in a good place right now\n Are you in Indonesia?",
#   'full_response': 'Output = Meme ini menyindir kondisi Indonesia yang sering dianggap penuh masalah atau tidak menyenangkan, baik dari segi sosial, ekonomi, atau politik. Ketika seseorang berkata "I\'m not in a good place right now" (Aku sedang tidak di tempat yang baik sekarang), lawan bicaranya langsung menebak "Are you in Indonesia?" (Apakah kamu di Indonesia?), seolah-olah Indonesia adalah tempat yang identik dengan situasi yang tidak baik. Pesan tersembunyi dari meme ini adalah banyak orang merasa bahwa hidup di Indonesia penuh tantangan atau masalah, sehingga ketika seseorang merasa tidak baik-baik saja, langsung diasosiasikan dengan tinggal di Indonesia.'},
#  {'id': 49,
#   'image_name': 'Meme_Data_49.jpg',
#   'ocr_txt': 'MANA ADA\n ORANG MISKIN\n DI NEGERI INI?',
#   'full_response': 'Output = Meme ini menyindir para pejabat atau orang kaya yang menutup mata terhadap kemiskinan di Indonesia. Meskipun ada orang miskin yang jelas-jelas ada di depan mereka, mereka pura-pura tidak melihat atau mengabaikan kenyataan tersebut. Pesan tersembunyi dari meme ini adalah kritik terhadap ketidakpedulian dan kurangnya empati dari pihak yang berkuasa terhadap masalah sosial di masyarakat.'},
#  {'id': 50,
#   'image_name': 'Meme_Data_50.jpg',
#   'ocr_txt': 'Dia kenapa?\n Keseringan nge-iya-in\n maunya orang',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang "terluka" atau "jatuh sakit" karena terlalu sering menuruti keinginan orang lain (selalu berkata "iya" demi menyenangkan orang lain). Pesan tersembunyinya adalah, jika kita terlalu sering mengorbankan diri sendiri demi orang lain, pada akhirnya kita sendiri yang akan merasa lelah, stres, atau bahkan "jatuh" secara mental maupun fisik. Meme ini mengingatkan agar jangan terlalu memaksakan diri untuk selalu menyenangkan orang lain.'},
#  {'id': 51,
#   'image_name': 'Meme_Data_51.jpg',
#   'ocr_txt': 'Permisi nyonya\n Aku Copet\n Aaa tolong dia mencuri tas ku\n Ambil sendiri dasar manja\n Kedzoliman akan terus\n ada bukan karena banyaknya orang-orang jahat\n Tapi karena diam nya\n orang-orang baik',
#   'full_response': 'Output = Meme ini menggambarkan situasi di mana kejahatan bisa terus terjadi bukan karena banyaknya orang jahat, tetapi karena orang-orang baik memilih untuk diam dan tidak bertindak. Dalam meme ini, Patrick dengan santainya mengaku sebagai copet dan mencuri tas SpongeBob, sementara orang lain yang melihat justru tidak membantu dan malah menyalahkan korban. Pesan tersembunyi dari meme ini adalah pentingnya peran orang baik untuk tidak diam saja ketika melihat ketidakadilan atau kejahatan, karena jika hanya diam, kejahatan akan terus ada dan berkembang.'},
#  {'id': 52,
#   'image_name': 'Meme_Data_52.jpg',
#   'ocr_txt': 'mau pacaran\n gak, jangan,\n \n MUKA: emang ada yang\n mau?',
#   'full_response': 'Output = Meme ini menggambarkan konflik batin antara otak (logika) dan hati (perasaan) tentang keinginan untuk pacaran. Otak ingin pacaran, hati menolak. Namun, pada akhirnya, wajah (penampilan fisik) malah merendahkan diri sendiri dengan berkata, “emang ada yang mau?” Artinya, meskipun ada keinginan dan perdebatan batin, pada akhirnya merasa minder atau tidak percaya diri karena merasa tidak ada yang mau dengan dirinya. Pesan tersembunyi dari meme ini adalah tentang rasa kurang percaya diri dan self-deprecating humor yang sering dialami oleh banyak orang.'},
#  {'id': 53,
#   'image_name': 'Meme_Data_53.jpg',
#   'ocr_txt': 'Gaji 2 juta tidak bersyukur\n Gaji 20 juta tapi bersyukur',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah bahwa rasa syukur sangat mempengaruhi kebahagiaan seseorang, bukan hanya jumlah gaji yang diterima. Pada gambar pertama, orang yang bergaji 2 juta tapi tidak bersyukur terlihat sedih dan tertekan. Sedangkan pada gambar kedua, orang yang bergaji 20 juta dan bersyukur terlihat tenang dan bahagia. Meme ini menyindir bahwa seberapa besar pun penghasilanmu, jika tidak bersyukur, kamu tetap akan merasa kurang dan tidak bahagia. Sebaliknya, dengan bersyukur, hidup akan terasa lebih damai dan menyenangkan.'},
#  {'id': 54,
#   'image_name': 'Meme_Data_54.jpg',
#   'ocr_txt': 'Alcohol\n  Weed\n Cocaine\n Liat tingkah pejabat konoha di berita',
#   'full_response': 'Output = Meme ini membandingkan efek dari alkohol, ganja, dan kokain yang membuat mata seseorang terlihat aneh atau merah, dengan efek melihat tingkah laku pejabat "Konoha" (referensi bercanda ke pejabat Indonesia) di berita yang justru membuat mata lebih parah lagi. Pesan tersembunyinya adalah, tingkah laku pejabat di berita sangat membuat stres atau "bikin sakit kepala" sampai-sampai lebih parah dari efek narkoba. Ini sindiran terhadap perilaku pejabat yang sering membuat masyarakat geleng-geleng kepala.'},
#  {'id': 55,
#   'image_name': 'Meme_Data_55.jpg',
#   'ocr_txt': 'TINGGAL\n TINGGAL\n TUNJUKIN\n TUNJUKIN\n IJASAH\n IJASAH\n ASLI\n SEWA PREMAN TANAH ABANG!',
#   'full_response': 'Output =  \nMeme ini menyindir fenomena di Indonesia di mana ketika seseorang diminta menunjukkan ijazah asli (misalnya untuk keperluan administrasi atau pekerjaan), ada orang yang malah panik atau takut karena ijazahnya mungkin tidak asli atau bermasalah. Alih-alih menunjukkan ijazah asli, mereka justru memilih “sewa preman Tanah Abang” untuk mengintimidasi atau menghindari masalah. Meme ini menggambarkan bagaimana orang-orang kadang lebih memilih jalan pintas atau kekerasan daripada menyelesaikan masalah dengan cara yang benar.'},
#  {'id': 56,
#   'image_name': 'Meme_Data_56.jpg',
#   'ocr_txt': 'TIDAK APA-APA KAWAN YANG PENTING SUDAH LOLOS PIALA\n DUNIA\n \n INDO 0-6 KORUT',
#   'full_response': 'Output = Meme ini menggambarkan sikap legowo atau menerima kekalahan dengan santai. Meskipun tim Indonesia kalah telak 0-6 dari Korea Utara, tokoh Patrick di meme ini tetap tersenyum dan berkata "tidak apa-apa kawan yang penting sudah lolos Piala Dunia". Pesan tersembunyinya adalah kadang dalam hidup, meskipun hasilnya buruk atau memalukan, yang penting adalah sudah mencapai tujuan utama (lolos Piala Dunia), jadi kekalahan besar pun tidak terlalu dipermasalahkan. Meme ini juga menyindir mentalitas "yang penting ikut" atau "yang penting sudah sampai target", meski hasil akhirnya kurang memuaskan.'},
#  {'id': 57,
#   'image_name': 'Meme_Data_57.jpg',
#   'ocr_txt': 'Mereka ga tau kalo aku sebenernya ga lulus\n Alumni\n Alumni\n Alumni\n Alumni',
#   'full_response': 'Meme ini menggambarkan seseorang yang merasa terasing di tengah-tengah para alumni yang sedang bersenang-senang. Teks "Mereka ga tau kalo aku sebenernya ga lulus" menunjukkan bahwa orang tersebut sebenarnya tidak lulus, namun tetap hadir di acara alumni dan berpura-pura seperti yang lain. Pesan tersembunyi dari meme ini adalah tentang perasaan minder, tidak percaya diri, atau merasa tidak pantas berada di suatu lingkungan karena menyimpan rahasia yang memalukan. Meme ini juga menyindir fenomena sosial di mana seseorang berusaha menutupi kekurangannya agar bisa diterima di lingkungan tertentu.'},
#  {'id': 58,
#   'image_name': 'Meme_Data_58.jpg',
#   'ocr_txt': 'Start Up Indonesia\n Marketer ga bisa marketing\n Anak IT ga bisa coding',
#   'full_response': 'Output = Meme ini menyindir kondisi start up di Indonesia yang sering kali memiliki tim yang tidak kompeten di bidangnya. Anak IT yang seharusnya jago coding ternyata tidak bisa coding, dan marketer yang seharusnya ahli marketing malah tidak bisa marketing. Kedua hal ini dianggap sebagai “kesamaan” yang sering ditemukan di start up Indonesia, sehingga meme ini menyoroti ironi dan masalah kualitas SDM di dunia start up lokal.'},
#  {'id': 59,
#   'image_name': 'Meme_Data_59.jpg',
#   'ocr_txt': 'Kenaikan Dollar Tidak Berpengaruh\n Ke Kita Katanya\n Emang Mie Ayam Ga Pake Gandum?',
#   'full_response': 'Output = Meme ini menyindir pernyataan bahwa kenaikan nilai tukar dollar tidak berpengaruh pada kehidupan masyarakat Indonesia. Padahal, mie ayam yang merupakan makanan favorit banyak orang Indonesia, terbuat dari mie yang bahan dasarnya adalah gandum, dan gandum biasanya diimpor dengan harga dollar. Jadi, jika dollar naik, harga gandum juga naik, dan otomatis harga mie ayam bisa ikut naik. Meme ini menyoroti ketidaksesuaian antara pernyataan pejabat atau pihak tertentu dengan realita di lapangan.'},
#  {'id': 60,
#   'image_name': 'Meme_Data_60.jpg',
#   'ocr_txt': 'Prabowo soal Aset Koruptor Disita: Apakah Adil Anaknya Menderita?\n Well, yes',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap pertanyaan apakah adil jika anak koruptor ikut menderita ketika aset orang tuanya yang korup disita negara. Dengan menggunakan gambar karakter dari film animasi yang menjawab "Well, yes", meme ini menegaskan bahwa memang sudah seharusnya anak koruptor ikut merasakan akibat dari perbuatan orang tuanya, karena harta yang dinikmati juga berasal dari hasil korupsi. Meme ini menyampaikan bahwa keadilan memang menuntut konsekuensi bagi keluarga koruptor, bukan hanya pelakunya saja.'},
#  {'id': 61,
#   'image_name': 'Meme_Data_61.jpg',
#   'ocr_txt': 'SAY THE LINE WOK\n KEKUATAN ASING\n AOWKWKOWKWK',
#   'full_response': 'Meme ini menggunakan format "Say the line!" dari The Simpsons, di mana sekelompok anak-anak meminta seseorang untuk mengucapkan kalimat yang sudah sangat terkenal dari dirinya. Dalam konteks ini, "Wok" diminta untuk mengatakan "KEKUATAN ASING", yang merupakan frasa yang sering diucapkan oleh tokoh tertentu di Indonesia saat membahas isu politik atau ekonomi yang dikaitkan dengan campur tangan pihak luar negeri.\n\nSetelah "Wok" mengucapkan kalimat tersebut, seluruh kelas langsung bersorak dan tertawa ("AOWKWKOWKWK"), menandakan bahwa kalimat itu sudah menjadi bahan candaan atau meme di kalangan masyarakat. \n\n**Pesan tersembunyi:**  \nMeme ini menyindir bagaimana frasa "kekuatan asing" sudah sangat melekat dan sering diulang-ulang oleh tokoh tertentu, sampai-sampai masyarakat menunggu-nunggu dan menertawakan setiap kali frasa itu diucapkan, karena sudah dianggap klise dan lucu.'},
#  {'id': 62,
#   'image_name': 'Meme_Data_62.jpg',
#   'ocr_txt': 'LU KETIKA TAU BURUNG DAN IKAN MIGRASI UNTUK NYARI TEMPAT MAKAN YG LEBIH BAIK\n SEDANGKAN LU DARI LAHIR SUSAH TAPI TETEP DISINI AJA SAMBIL MERATAPI NASIB',
#   'full_response': 'Output = Meme ini menggambarkan perasaan sedih dan putus asa seseorang yang merasa hidupnya tidak berubah dan tetap sulit, sementara hewan seperti burung dan ikan saja bisa berpindah tempat untuk mencari kehidupan yang lebih baik. Pesan tersembunyinya adalah sindiran terhadap orang-orang yang merasa terjebak dalam kesulitan hidup, namun tidak berani atau tidak mampu mengambil langkah untuk mengubah nasib, sehingga hanya bisa meratapi keadaan tanpa melakukan perubahan.'},
#  {'id': 63,
#   'image_name': 'Meme_Data_63.jpg',
#   'ocr_txt': 'Pemerintah yg\n bikin aturan judol ilegal\n Pemerintah yg prihatin rakyatnya\n terlibat judol\n Pemerintah yg\n ternyata jadi\n bandar judol',
#   'full_response': 'Meme ini menggunakan template Spider-Man saling menunjuk, yang biasanya dipakai untuk menunjukkan kemunafikan atau saling menyalahkan padahal sama saja. Teks pada meme ini menggambarkan tiga peran pemerintah: membuat aturan judi online ilegal, prihatin rakyatnya terlibat judi online, dan ternyata pemerintah sendiri yang jadi bandar judi online.\n\nPesan tersembunyi dari meme ini adalah sindiran terhadap pemerintah yang seolah-olah menentang dan prihatin terhadap judi online, padahal diduga justru terlibat atau mendapat keuntungan dari praktik tersebut. Meme ini menyoroti adanya kemunafikan dan konflik kepentingan di tubuh pemerintah terkait isu judi online.'},
#  {'id': 64,
#   'image_name': 'Meme_Data_64.jpg',
#   'ocr_txt': 'enak ya kalo ga\n punya otak.. idupnya ga pusing',
#   'full_response': 'Output = Meme ini menyindir orang-orang yang terlihat santai dan tidak pernah pusing menghadapi masalah, seolah-olah mereka tidak perlu berpikir keras atau memikirkan konsekuensi. Pesan tersembunyinya adalah, kadang orang yang terlalu cuek atau tidak peduli dianggap seperti "tidak punya otak", sehingga hidupnya terasa lebih mudah dan tidak banyak beban pikiran.'},
#  {'id': 65,
#   'image_name': 'Meme_Data_65.jpg',
#   'ocr_txt': 'PUASA\n WINRATE 100%\n \n NGGAK PERNAH\n TARAWIH',
#   'full_response': 'Meme ini menggambarkan seseorang yang merasa bangga karena selalu berhasil menjalankan puasa (winrate 100%), namun di sisi lain, dia tidak pernah melaksanakan salat tarawih. Pesan tersembunyi dari meme ini adalah sindiran terhadap orang-orang yang hanya fokus pada satu ibadah (puasa) dan mengabaikan ibadah lainnya yang juga penting selama bulan Ramadan (seperti tarawih). Meme ini menyoroti fenomena di mana seseorang merasa sudah cukup baik hanya dengan berpuasa, padahal seharusnya ibadah lain juga dijalankan agar ibadah Ramadan lebih sempurna.'},
#  {'id': 66,
#   'image_name': 'Meme_Data_66.jpg',
#   'ocr_txt': 'APRIL MOP?\n INI INDONESIA BUNG! KITA DIKERJAIN SETIAP HARI',
#   'full_response': 'Output = Meme ini menyindir kehidupan di Indonesia yang penuh dengan kejadian atau kebijakan yang terasa seperti “prank” atau lelucon setiap hari, bukan hanya saat April Mop. Gambar anak kecil yang tertawa terbahak-bahak memperkuat kesan sarkasme, seolah-olah masyarakat Indonesia sudah terbiasa “dikerjain” oleh situasi atau pemerintah, sehingga hari-hari di Indonesia terasa seperti April Mop setiap saat.'},
#  {'id': 67,
#   'image_name': 'Meme_Data_67.jpg',
#   'ocr_txt': 'besok sahur terakhir, puasa terakhir, ngabuburit terakhir, buka puasa terakhir dan teraweh terakhir',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah perasaan campur aduk yang dirasakan seseorang ketika bulan Ramadan akan berakhir. Teks yang menyebutkan "sahur terakhir, puasa terakhir, ngabuburit terakhir, buka puasa terakhir, dan teraweh terakhir" menggambarkan momen-momen spesial di bulan Ramadan yang akan segera berakhir, sehingga menimbulkan rasa sedih dan kehilangan. Ekspresi wajah datar pada gambar orang yang memakai peci menambah kesan hampa dan tidak siap menghadapi berakhirnya Ramadan. Meme ini mewakili perasaan banyak orang yang berat meninggalkan suasana Ramadan.'},
#  {'id': 68,
#   'image_name': 'Meme_Data_68.jpg',
#   'ocr_txt': 'BERFUNGSI AJA ENGGAK, MASA MAU DWIFUNGSI?',
#   'full_response': 'Output = Meme ini menyindir keras suatu lembaga, institusi, atau pihak tertentu yang dianggap tidak menjalankan tugas utamanya dengan baik, tapi malah ingin menambah peran atau fungsi lain (dwifungsi). Pesan tersembunyinya adalah: "Tugas utama saja belum beres, kok malah mau nambah tanggung jawab lagi?" Biasanya sindiran seperti ini ditujukan ke institusi pemerintah atau pejabat yang kinerjanya dipertanyakan, namun ingin memperluas wewenang atau peran mereka.'},
#  {'id': 69,
#   'image_name': 'Meme_Data_69.jpg',
#   'ocr_txt': 'Warga Samarinda Dijadikan Tersangka usai Lapor Polisi soal Propertinya Dikuasai Preman\n \n GA HABIS THINKING',
# ...
#  {'id': 209,
#   'image_name': 'Meme_Data_209.jpg',
#   'ocr_txt': 'gini amat nganggur\n cuma bengong doang udah 20 menit',
#   'full_response': 'Output = Meme ini menggambarkan perasaan seseorang yang sedang menganggur (tidak punya pekerjaan) dan merasa sangat bosan hingga hanya bisa melamun atau bengong selama 20 menit tanpa melakukan apa-apa. Gambar karakter yang terlihat sedih dan menatap keluar jendela memperkuat kesan kesepian dan kebosanan yang sering dirasakan oleh orang yang sedang tidak punya aktivitas atau pekerjaan. Pesan tersembunyinya adalah betapa membosankannya hidup saat tidak ada kegiatan, dan ini sering dialami oleh para pengangguran.'},
#  {'id': 210,
#   'image_name': 'Meme_Data_210.jpg',
#   'ocr_txt': 'Wah udah jam 7 pagi,\n Tidur lagi ah,kan pengangguran',
#   'full_response': 'Output = Meme ini menggambarkan kehidupan seorang pengangguran yang tidak memiliki kewajiban untuk bangun pagi seperti orang yang bekerja atau sekolah. Patrick, karakter di gambar, merasa tidak perlu terburu-buru bangun meskipun sudah pagi karena tidak ada aktivitas penting yang harus dilakukan. Pesan tersembunyi dari meme ini adalah sindiran lucu terhadap kehidupan pengangguran yang santai dan bebas dari rutinitas pagi, namun juga bisa menjadi sindiran bahwa menjadi pengangguran membuat seseorang kehilangan motivasi untuk produktif.'},
#  {'id': 211,
#   'image_name': 'Meme_Data_211.jpg',
#   'ocr_txt': 'Kerja dimana Sekarang bang\n \n PT\n widih pl mana kalau boleh lau\n Pengangguran Tetap',
#   'full_response': 'Output =  \nMeme ini menggambarkan situasi ketika seseorang ditanya soal tempat kerjanya, lalu menjawab singkat "PT" (yang biasanya merujuk pada perusahaan), sehingga orang lain penasaran dan bertanya lebih lanjut. Namun, ternyata "PT" yang dimaksud adalah singkatan dari "Pengangguran Tetap", alias tidak bekerja sama sekali. Meme ini menyindir orang-orang yang suka pamer atau menutupi status penganggurannya dengan jawaban yang ambigu atau sok keren, padahal kenyataannya mereka tidak bekerja.'},
#  {'id': 212,
#   'image_name': 'Meme_Data_212.jpg',
#   'ocr_txt': 'cocok ni\n buat tambang\n nikel',
#   'full_response': 'Meme ini menampilkan seseorang yang sedang menikmati pemandangan alam yang indah, namun diberi tulisan "cocok ni buat tambang nikel". Pesan tersembunyi dari meme ini adalah sindiran terhadap kebijakan atau praktik eksploitasi alam di Indonesia, khususnya terkait tambang nikel. Meme ini mengkritik bagaimana keindahan alam yang seharusnya dijaga justru sering dianggap sebagai lahan potensial untuk pertambangan, tanpa memikirkan dampak kerusakan lingkungan yang bisa terjadi.'},
#  {'id': 213,
#   'image_name': 'Meme_Data_213.jpg',
#   'ocr_txt': 'Temen gue mah lengkap\n Ada yang suka\n ngomongin gue dari belakang Ada yang suka minjem duit Ada yang suka minjem duit dan ngomongin gue dari belakang',
#   'full_response': 'Output = Meme ini menyindir tentang tipe-tipe teman yang sering ditemui dalam kehidupan sehari-hari. Ada teman yang suka membicarakan kita di belakang, ada yang suka meminjam uang, dan bahkan ada yang melakukan keduanya sekaligus. Pesan tersembunyinya adalah, meskipun punya banyak teman, tidak semuanya benar-benar baik atau tulus. Kadang, teman justru bisa membawa masalah atau drama dalam hidup kita.'},
#  {'id': 214,
#   'image_name': 'Meme_Data_214.jpg',
#   'ocr_txt': 'CNN Nasional\n Jokowi: Masyarakat Harus Aktif Sampaikan Kritik dan Masukan\n masyarakat\n UU ITE',
#   'full_response': 'Meme ini menggambarkan kontradiksi antara pernyataan Presiden Jokowi yang meminta masyarakat untuk aktif menyampaikan kritik dan masukan, dengan kenyataan di lapangan di mana masyarakat justru merasa terancam oleh UU ITE saat ingin mengkritik. Gambar papan catur menunjukkan pion (masyarakat) yang terjepit oleh kuda (masyarakat sendiri) dan benteng (UU ITE), menggambarkan bahwa masyarakat sulit bergerak bebas untuk menyampaikan kritik karena adanya ancaman hukum dari UU ITE. Pesan tersembunyi dari meme ini adalah kritik terhadap kebebasan berpendapat di Indonesia yang masih dibatasi oleh regulasi seperti UU ITE, sehingga masyarakat merasa tidak benar-benar bebas untuk mengkritik pemerintah.'},
#  {'id': 215,
#   'image_name': 'Meme_Data_215.jpg',
#   'ocr_txt': 'SOLD OUT\n SOLD OUT\n SOLD OUT\n \n READY STOCK',
#   'full_response': 'Output =  \nMeme ini membandingkan pasangan-pasangan yang sudah menikah atau berpasangan (dengan tulisan "SOLD OUT" yang artinya sudah tidak tersedia atau sudah ada yang punya) dengan satu orang yang tampil sendiri dan berpakaian aneh (dengan tulisan "READY STOCK" yang artinya masih tersedia atau masih jomblo). Pesan tersembunyi dari meme ini adalah sindiran lucu untuk para jomblo, bahwa semua orang yang menarik sudah punya pasangan, sedangkan yang masih "ready stock" adalah orang yang dianggap kurang menarik atau aneh. Meme ini menggambarkan perasaan para jomblo yang merasa tersisa dan belum menemukan pasangan.'},
#  {'id': 216,
#   'image_name': 'Meme_Data_216.jpg',
#   'ocr_txt': 'Nunggu itu selalu ngeselin.\n Apalagi nunggunya hal yang ngga pasti',
#   'full_response': 'Output =  \nMeme ini menggambarkan seekor kucing yang terlihat bosan dan lelah menunggu di pinggir pagar, seolah-olah sudah menunggu sangat lama tanpa kepastian. Pesan tersembunyi dari meme ini adalah menunggu sesuatu yang tidak pasti itu sangat melelahkan dan membuat frustrasi, sama seperti kucing di gambar yang terlihat pasrah dan tidak bersemangat. Meme ini sering digunakan untuk menyindir perasaan orang yang sedang menunggu kepastian, misalnya dalam hubungan atau pekerjaan, yang akhirnya hanya membuat lelah dan kecewa.'},
#  {'id': 217,
#   'image_name': 'Meme_Data_217.jpg',
#   'ocr_txt': 'SEKARANG\n ANAK JAMAN GAK AKAN TAU\n \n HEBATNYA DUET MAUT YANG SATU INI',
#   'full_response': 'Meme ini menggambarkan dua anak kecil berpakaian seperti biksu Shaolin, salah satunya sedang serius bermain Game Boy, sementara yang lain tampak santai dan bergaya dengan kacamata hitam. Teksnya mengatakan, "Anak jaman sekarang gak akan tau hebatnya duet maut yang satu ini."\n\nPesan tersembunyi dari meme ini adalah nostalgia terhadap masa kecil generasi 90-an atau awal 2000-an, di mana bermain Game Boy dan menonton film-film kungfu Shaolin adalah hal yang sangat populer dan menyenangkan. Meme ini menyindir bahwa anak-anak zaman sekarang tidak akan pernah merasakan serunya kombinasi hiburan sederhana seperti ini, yang dulu dianggap sangat keren dan legendaris.'},
#  {'id': 218,
#   'image_name': 'Meme_Data_218.jpg',
#   'ocr_txt': 'Namanya juga hidup. Tuhan yang nentuin, kita yang jalanin, orang lain yang ngomentarin.\n TERUS?\n GUE PEDULI?',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah tentang sikap cuek terhadap komentar atau penilaian orang lain tentang hidup kita. Dalam hidup, memang sudah biasa jika orang lain suka mengomentari apa yang kita lakukan, padahal yang menjalani adalah kita sendiri dan yang menentukan adalah Tuhan. Ekspresi orang di gambar yang mengangkat bahu dan tulisan "TERUS? GUE PEDULI?" menegaskan bahwa komentar orang lain tidak penting dan tidak perlu terlalu dipikirkan. Intinya, jalani hidup sesuai dengan keinginan sendiri tanpa terlalu memusingkan omongan orang lain.'},
#  {'id': 219,
#   'image_name': 'Meme_Data_219.jpg',
#   'ocr_txt': 'janganserius\n Toilet Idaman Para Gamers',
#   'full_response': 'Meme ini menunjukkan beberapa orang sedang bermain game di toilet, dengan layar besar di depan mereka. Teks "Toilet Idaman Para Gamers" dan watermark "janganserius" menambah unsur humor.\n\nPesan tersembunyi dari meme ini adalah menggambarkan betapa para gamers sangat suka bermain game hingga mereka ingin bisa bermain di mana saja, bahkan saat di toilet. Toilet dengan fasilitas gaming seperti ini adalah impian para gamers yang tidak ingin melewatkan waktu bermain, bahkan saat melakukan aktivitas lain. Meme ini juga menyindir kebiasaan gamers yang sulit lepas dari game, dan mengajak penonton untuk tidak terlalu serius menanggapi keinginan-keinginan kocak seperti ini.'},
#  {'id': 220,
#   'image_name': 'Meme_Data_220.jpg',
#   'ocr_txt': 'APA ANDA PERNAH MERASAKANNYA??\n yg duduk paling rapi PULANG DULUAN',
#   'full_response': 'Output = Meme ini menggambarkan pengalaman masa kecil di sekolah dasar di Indonesia, di mana guru sering memberikan "hadiah" kepada murid yang duduk paling rapi, yaitu boleh pulang lebih dulu. Pesan tersembunyinya adalah nostalgia akan masa-masa sekolah dulu, di mana murid-murid berlomba-lomba duduk rapi agar bisa pulang lebih awal. Meme ini juga menyindir kebiasaan guru yang menggunakan cara sederhana untuk mendisiplinkan murid.'},
#  {'id': 221,
#   'image_name': 'Meme_Data_221.jpg',
#   'ocr_txt': 'CEWEK YANG SUKA GONTA GANTI DISPLAY PICTURE\n PASTI ADA COWOK YANG DIA SUKA DI KONTAKNYA',
#   'full_response': 'Output = Meme ini menyindir cewek yang sering mengganti foto profil (display picture) di media sosial. Pesan tersembunyinya adalah biasanya cewek melakukan itu karena ingin menarik perhatian cowok yang dia suka di daftar kontaknya. Jadi, gonta-ganti foto profil dianggap sebagai kode atau usaha untuk dilihat dan diperhatikan oleh cowok incarannya.'},
#  {'id': 222,
#   'image_name': 'Meme_Data_222.jpg',
#   'ocr_txt': 'NGENES\n TANGGAL TUA, KELAPERAN,\n STOK TINGGAL 1, PAS DISARING JATOH',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah tentang betapa sial dan sedihnya situasi ketika sedang tanggal tua (akhir bulan, uang menipis), perut lapar, stok makanan cuma tersisa satu (mie instan), tapi saat mau dimasak malah mie-nya jatuh ke wastafel saat disaring. Meme ini menggambarkan perasaan apes dan putus asa yang sering dialami anak kos atau siapa saja yang sedang kepepet, di mana harapan terakhir untuk makan pun gagal karena kesalahan kecil. Intinya, meme ini menyoroti momen-momen ngenes (menyedihkan) dalam hidup sehari-hari.'},
#  {'id': 223,
#   'image_name': 'Meme_Data_223.jpg',
#   'ocr_txt': 'LAKI BANGET ITU\n BENSIN MOTOR ABIS MOTORNYA LANGSUNG DIGENDONG',
#   'full_response': 'Output = Meme ini menyindir secara lucu tentang definisi “laki banget” atau sangat jantan. Biasanya, laki-laki dianggap keren jika bisa mengatasi masalah dengan cara yang ekstrem atau tidak biasa. Dalam gambar, ketika motor kehabisan bensin, bukannya mencari solusi biasa seperti mendorong motor atau mencari bensin, orang di gambar malah langsung menggendong motornya di pundak. Ini adalah tindakan yang sangat berlebihan dan tidak masuk akal, sehingga meme ini sebenarnya ingin menertawakan standar “kejantanan” yang sering dilebih-lebihkan di masyarakat. Pesan tersembunyinya adalah: kadang-kadang, orang melakukan hal-hal konyol hanya demi terlihat “jantan” di mata orang lain.'},
#  {'id': 224,
#   'image_name': 'Meme_Data_224.jpg',
#   'ocr_txt': 'DI DEPAN NGAKUNYA SAYANG\n ARI BELAKANG MALAH NYAKITI',
#   'full_response': 'Output = Meme ini menggambarkan seseorang yang di depan bersikap manis dan mengaku sayang, tapi di belakang justru menusuk atau menyakiti. Gambar seorang wanita memeluk pria dari depan, namun di belakang pria tersebut tertancap panah, melambangkan pengkhianatan atau perilaku munafik. Pesan tersembunyi dari meme ini adalah hati-hati dengan orang yang terlihat baik di depan, tapi diam-diam menyakiti dari belakang.'},
#  {'id': 225,
#   'image_name': 'Meme_Data_225.jpg',
#   'ocr_txt': 'ADA 3 TYPE ORANG SAAT MENANG DI GAME ONLINE\n orang yg ga ngetik apa2\n "AOWKAWKWK EZ BGT DEK DEK"\n GG BRO',
#   'full_response': 'Output = Meme ini menggambarkan tiga tipe orang yang berbeda saat mereka menang dalam game online. Ada yang diam saja tanpa mengetik apapun, ada yang sombong dan mengejek lawan dengan kata-kata seperti "AOWKAWKWK EZ BGT DEK DEK" (menunjukkan kemenangan yang mudah dan meremehkan lawan), dan ada juga yang sportif dengan mengucapkan "GG BRO" (Good Game Bro) sebagai bentuk penghargaan kepada lawan. Pesan tersembunyinya adalah setiap orang punya cara sendiri dalam merespon kemenangan, mulai dari yang kalem, yang suka pamer, sampai yang tetap sopan dan menghargai lawan.'},
#  {'id': 226,
#   'image_name': 'Meme_Data_226.jpg',
#   'ocr_txt': ': "Kamu dari jawa ya!" Iyaa, kamu jawa juga?\n : "Bukan, aku tinggal di bandung, Tapi mamah papahku asli Jakarta"\n Bandung, Jakarta\n yang dimaksud:',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah sindiran terhadap orang-orang yang sering menganggap Bandung dan Jakarta bukan bagian dari Pulau Jawa, padahal secara geografis kedua kota tersebut jelas berada di Pulau Jawa. Meme ini menyoroti fenomena umum di mana orang-orang dari Bandung atau Jakarta merasa identitasnya berbeda dari "orang Jawa" pada umumnya, padahal secara lokasi mereka tetap berada di Jawa. Jadi, meme ini menertawakan kebingungan identitas dan persepsi yang keliru tentang geografi dan budaya di Indonesia.'},
#  {'id': 227,
#   'image_name': 'Meme_Data_227.jpg',
#   'ocr_txt': 'Pas kecil liat orang dewasa pacaran, pas sudah dewasa malah lihat anak kecil yang pacaran aaaaarrrrrrrgggg',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah tentang perubahan perspektif seiring bertambahnya usia. Saat masih kecil, kita sering merasa heran atau iri melihat orang dewasa pacaran. Namun, ketika sudah dewasa, justru kita yang merasa aneh atau bahkan kesal melihat anak-anak kecil sudah mulai pacaran. Ekspresi wajah di gambar yang terlihat marah dan frustasi memperkuat perasaan "nggak terima" atau "kesal" karena realita yang berbalik dari ekspektasi masa kecil. Meme ini juga menyindir fenomena zaman sekarang di mana anak-anak kecil sudah mulai pacaran, yang membuat orang dewasa merasa tidak nyaman atau kaget.'},
#  {'id': 228,
#   'image_name': 'Meme_Data_228.jpg',
#   'ocr_txt': 'SINGAPORE AIRLINES\n 1. Untung 47 Trilliun 2. Bandara 2 3. Penduduk 6.3 juta\n Garuda Indonesia\n 1. Rugi 1.2 Trilliun\n 2. Bandara status international 17 3. penduduk 280 juta',
#   'full_response': 'Output = Meme ini menyindir perbandingan antara Singapore Airlines dan Garuda Indonesia. Meskipun Singapore Airlines hanya memiliki 2 bandara dan jumlah penduduk Singapura jauh lebih sedikit (6,3 juta), mereka bisa meraih keuntungan besar (47 triliun). Sementara Garuda Indonesia, dengan jumlah bandara internasional lebih banyak (17) dan penduduk Indonesia yang jauh lebih besar (280 juta), justru mengalami kerugian (1,2 triliun). Pesan tersembunyi dari meme ini adalah mempertanyakan kinerja dan efisiensi Garuda Indonesia, serta menyoroti adanya masalah manajemen atau sistem di Indonesia yang membuat potensi besar tidak dimanfaatkan dengan baik.'},
#  {'id': 229,
#   'image_name': 'Meme_Data_229.jpg',
#   'ocr_txt': 'Yudi\n \n P\n \n Bls\n \n Besok pake baju apa\n Pramuka\n \n Ok acc \n day 1 nge frank yudi',
#   'full_response': 'Pesan tersembunyi dari meme ini adalah tentang seseorang yang dikerjai (di-prank) oleh temannya. Dalam chat, Yudi bertanya besok harus memakai baju apa, lalu dijawab "Pramuka". Namun, pada kenyataannya, semua siswa memakai seragam sekolah biasa, hanya Yudi yang memakai seragam Pramuka sehingga dia jadi pusat perhatian dan terlihat berbeda sendiri. Meme ini menggambarkan momen lucu ketika seseorang menjadi korban prank karena terlalu percaya dengan jawaban temannya tanpa mengecek lagi ke orang lain.'},
#  {'id': 230,
#   'image_name': 'Meme_Data_230.jpg',
#   'ocr_txt': 'Dua tipe manusia:\n Kamu rajin belajar biar bisa bantu\n mereka yang butuh\n Dia itu intel',
#   'full_response': 'Output = Meme ini menggambarkan dua tipe manusia dalam menanggapi situasi yang sama. Di sisi kiri, orang tua mengajarkan anaknya untuk rajin belajar agar bisa membantu orang yang membutuhkan, seperti petugas kebersihan. Sementara di sisi kanan, orang tua justru berprasangka dan mengatakan bahwa petugas kebersihan itu adalah intel (mata-mata). Pesan tersembunyi dari meme ini adalah bahwa setiap orang bisa melihat situasi dari sudut pandang yang berbeda, ada yang positif dan ada yang negatif, tergantung pola pikir dan cara mendidik.'}]

# %%
# Create results DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#       id         image_name  \
# 0      1    Meme_Data_1.jpg
# 1      2    Meme_Data_2.jpg
# 2      3    Meme_Data_3.jpg
# 3      4    Meme_Data_4.jpg
# 4      5    Meme_Data_5.jpg
# ..   ...                ...
# 225  226  Meme_Data_226.jpg
# 226  227  Meme_Data_227.jpg
# 227  228  Meme_Data_228.jpg
# 228  229  Meme_Data_229.jpg
# 229  230  Meme_Data_230.jpg
#
#                                                ocr_txt  \
# 0    COWOK JAMAN SEKARANG PENGEN PUNYA PACAR CANTIK...
# 1    ayat suci dalam bio bukan jaminan kalo\n dia o...
# 2    Rare\n Medium Rare\n Medium\n Medium Well\n We...
# 3    KITA MAH ORANG SUSAH\n INWE\n SUSAH DILAWAN MA...
# 4    KALIAN GA PILIH DIA KARENA BEDA ALIRAN DAN FAN...
# ..                                                 ...
# 225  : "Kamu dari jawa ya!" Iyaa, kamu jawa juga?\n...
# 226  Pas kecil liat orang dewasa pacaran, pas sudah...
# 227  SINGAPORE AIRLINES\n 1. Untung 47 Trilliun 2. ...
# 228  Yudi\n \n P\n \n Bls\n \n Besok pake baju apa\...
# 229  Dua tipe manusia:\n Kamu rajin belajar biar bi...
#
#                                          full_response
# 0    Output = Meme ini menyindir cowok-cowok zaman ...
# 1    Output = Meme ini menyampaikan pesan bahwa men...
# 2    Meme ini membandingkan tingkat kematangan dagi...
# 3    Output = Meme ini menggunakan permainan kata y...
# 4    Pesan tersembunyi dari meme ini adalah sindira...
# ..                                                 ...
# 225  Pesan tersembunyi dari meme ini adalah sindira...
# 226  Pesan tersembunyi dari meme ini adalah tentang...
# 227  Output = Meme ini menyindir perbandingan antar...
# 228  Pesan tersembunyi dari meme ini adalah tentang...
# 229  Output = Meme ini menggambarkan dua tipe manus...
#
# [230 rows x 4 columns]

# %%
def extract_combined_robust(response):
    # Try to extract after 'output ='
    match_output = re.search(r'output\s*=\s*([\s\S]*)', response, re.IGNORECASE)
    if match_output:
        return match_output.group(1).strip()
    # Try to extract after 'Pesan tersembunyi dari meme ini adalah:'
    match_pesan = re.search(r'Pesan tersembunyi dari meme ini adalah:\s*([\s\S]*)', response, re.IGNORECASE)
    if match_pesan:
        return match_pesan.group(1).strip()
    # Fallback to original response
    return response.strip()

results_df['output_extracted'] = results_df['full_response'].apply(lambda x: extract_combined_robust(str(x)))

# %%
# Example usage:
response = results_df['output_extracted'][141]
print(extract_combined_robust(response))
# Out:
# Meme ini menyindir laki-laki yang suka mengeluh atau memprotes pacarnya karena tidak bisa memasak, digambarkan dengan wajah yang terlihat marah atau tidak dewasa. Sementara itu, laki-laki yang bisa memasak sendiri digambarkan dengan sosok yang lebih keren dan dewasa. Intinya, laki-laki yang bisa memasak sendiri dianggap lebih keren dan dewasa daripada yang hanya bisa mengeluh ke pasangannya.

# %%
results_df
# Out:
#       id         image_name  \
# 0      1    Meme_Data_1.jpg
# 1      2    Meme_Data_2.jpg
# 2      3    Meme_Data_3.jpg
# 3      4    Meme_Data_4.jpg
# 4      5    Meme_Data_5.jpg
# ..   ...                ...
# 225  226  Meme_Data_226.jpg
# 226  227  Meme_Data_227.jpg
# 227  228  Meme_Data_228.jpg
# 228  229  Meme_Data_229.jpg
# 229  230  Meme_Data_230.jpg
#
#                                                ocr_txt  \
# 0    COWOK JAMAN SEKARANG PENGEN PUNYA PACAR CANTIK...
# 1    ayat suci dalam bio bukan jaminan kalo\n dia o...
# 2    Rare\n Medium Rare\n Medium\n Medium Well\n We...
# 3    KITA MAH ORANG SUSAH\n INWE\n SUSAH DILAWAN MA...
# 4    KALIAN GA PILIH DIA KARENA BEDA ALIRAN DAN FAN...
# ..                                                 ...
# 225  : "Kamu dari jawa ya!" Iyaa, kamu jawa juga?\n...
# 226  Pas kecil liat orang dewasa pacaran, pas sudah...
# 227  SINGAPORE AIRLINES\n 1. Untung 47 Trilliun 2. ...
# 228  Yudi\n \n P\n \n Bls\n \n Besok pake baju apa\...
# 229  Dua tipe manusia:\n Kamu rajin belajar biar bi...
#
#                                          full_response  \
# 0    Output = Meme ini menyindir cowok-cowok zaman ...
# 1    Output = Meme ini menyampaikan pesan bahwa men...
# 2    Meme ini membandingkan tingkat kematangan dagi...
# 3    Output = Meme ini menggunakan permainan kata y...
# 4    Pesan tersembunyi dari meme ini adalah sindira...
# ..                                                 ...
# 225  Pesan tersembunyi dari meme ini adalah sindira...
# 226  Pesan tersembunyi dari meme ini adalah tentang...
# 227  Output = Meme ini menyindir perbandingan antar...
# 228  Pesan tersembunyi dari meme ini adalah tentang...
# 229  Output = Meme ini menggambarkan dua tipe manus...
#
#                                       output_extracted
# 0    Meme ini menyindir cowok-cowok zaman sekarang ...
# 1    Meme ini menyampaikan pesan bahwa menampilkan ...
# 2    Rendang, makanan khas Indonesia (khususnya Min...
# 3    Meme ini menggunakan permainan kata yang lucu....
# 4    Pesan tersembunyi dari meme ini adalah sindira...
# ..                                                 ...
# 225  Pesan tersembunyi dari meme ini adalah sindira...
# 226  Pesan tersembunyi dari meme ini adalah tentang...
# 227  Meme ini menyindir perbandingan antara Singapo...
# 228  Pesan tersembunyi dari meme ini adalah tentang...
# 229  Meme ini menggambarkan dua tipe manusia dalam ...
#
# [230 rows x 5 columns]

# %%
# Save results
results_df.to_csv('gpt4.1_results.csv', index=False)
